# %% [markdown]
# <img src = "https://hacktiv8.com/assets/img/logos/hacktiv8-text-black.svg" width = 400>
# <h1 align=center><font size = 5>Hacktiv8-Online Python For Data Science // Basic Visualization</font></h1>

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('googleplaystore.csv')

print ('Data read into a pandas dataframe!')
# Out:
# Data read into a pandas dataframe!

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(6)
# Out:
#                 Total   Percent
# Rating           1474  0.135965
# Current Ver         8  0.000738
# Android Ver         3  0.000277
# Content Rating      1  0.000092
# Type                1  0.000092
# Last Updated        0  0.000000

# %%
df.dropna(how ='any', inplace = True)

# %%
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(6)
# Out:
#                 Total  Percent
# Android Ver         0      0.0
# Current Ver         0      0.0
# Last Updated        0      0.0
# Genres              0      0.0
# Content Rating      0      0.0
# Price               0      0.0

# %%
print( len(df['Category'].unique()) , "categories")

print("\n", df['Category'].unique())
# Out:
# 33 categories
#
#  ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION']

# %%
data_category = df.groupby('Category').count()

# %%
data_category
# Out:
#                       App  Rating  Reviews  Size  Installs  Type  Price  \
# Category
# ART_AND_DESIGN         61      61       61    61        61    61     61
# AUTO_AND_VEHICLES      73      73       73    73        73    73     73
# BEAUTY                 42      42       42    42        42    42     42
# BOOKS_AND_REFERENCE   178     178      178   178       178   178    178
# BUSINESS              303     303      303   303       303   303    303
# COMICS                 58      58       58    58        58    58     58
# COMMUNICATION         328     328      328   328       328   328    328
# DATING                195     195      195   195       195   195    195
# EDUCATION             155     155      155   155       155   155    155
# ENTERTAINMENT         149     149      149   149       149   149    149
# EVENTS                 45      45       45    45        45    45     45
# FAMILY               1746    1746     1746  1746      1746  1746   1746
# ...

# %%
df[['Category', 'Rating']]
# Out:
#                   Category  Rating
# 0           ART_AND_DESIGN     4.1
# 1           ART_AND_DESIGN     3.9
# 2           ART_AND_DESIGN     4.7
# 3           ART_AND_DESIGN     4.5
# 4           ART_AND_DESIGN     4.3
# ...                    ...     ...
# 10834               FAMILY     4.0
# 10836               FAMILY     4.5
# 10837               FAMILY     5.0
# 10839  BOOKS_AND_REFERENCE     4.5
# 10840            LIFESTYLE     4.5
#
# [9360 rows x 2 columns]

# %%
df.groupby('Category').sum()
# Out:
#                      Rating
# Category
# ART_AND_DESIGN        267.0
# AUTO_AND_VEHICLES     305.9
# BEAUTY                179.7
# BOOKS_AND_REFERENCE   773.6
# BUSINESS             1248.8
# COMICS                241.0
# COMMUNICATION        1364.0
# DATING                774.3
# EDUCATION             680.3
# ENTERTAINMENT         614.8
# EVENTS                199.6
# FAMILY               7319.9
# FINANCE              1334.6
# FOOD_AND_DRINK        454.2
# GAME                 4702.1
# HEALTH_AND_FITNESS   1270.3
# HOUSE_AND_HOME        319.0
# LIBRARIES_AND_DEMO    267.5
# LIFESTYLE            1285.8
# MAPS_AND_NAVIGATION   502.4
# MEDICAL              1466.2
# NEWS_AND_MAGAZINES    962.8
# PARENTING             215.0
# PERSONALIZATION      1352.6
# PHOTOGRAPHY          1328.9
# PRODUCTIVITY         1478.2
# SHOPPING             1013.8
# SOCIAL               1102.2
# SPORTS               1347.3
# TOOLS                2966.6
# TRAVEL_AND_LOCAL      928.7
# ...

# %%
df_Category = df.groupby('Category').sum()
df_Category.head()
# Out:
#                      Rating
# Category
# ART_AND_DESIGN        267.0
# AUTO_AND_VEHICLES     305.9
# BEAUTY                179.7
# BOOKS_AND_REFERENCE   773.6
# BUSINESS             1248.8

# %%
df_Category.plot(kind='line',figsize=(14, 8))

plt.title('Category Data by Rate')
plt.ylabel('Rate')
plt.xlabel('Category')
plt.show()

# %%
df.Category.unique
# Out:
# <bound method Series.unique of 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10834                 FAMILY
# 10836                 FAMILY
# 10837                 FAMILY
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 9360, dtype: object>

# %%
df.set_index('Category', inplace=True)

# %%
df.columns.values
# Out:
# array(['App', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price',
#        'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'], dtype=object)

# %%
df.reset_index(inplace=True)

# %%
df[['Category', 'Rating']]
# Out:
#                  Category  Rating
# 0          ART_AND_DESIGN     4.1
# 1          ART_AND_DESIGN     3.9
# 2          ART_AND_DESIGN     4.7
# 3          ART_AND_DESIGN     4.5
# 4          ART_AND_DESIGN     4.3
# ...                   ...     ...
# 9355               FAMILY     4.0
# 9356               FAMILY     4.5
# 9357               FAMILY     5.0
# 9358  BOOKS_AND_REFERENCE     4.5
# 9359            LIFESTYLE     4.5
#
# [9360 rows x 2 columns]

# %%
df[df['Category'] == 'COMICS']
# Out:
#      Category                                                App  Rating  \
# 285    COMICS                         LINE WEBTOON - Free Comics     4.5
# 286    COMICS           Manga Master - Best manga & comic reader     4.6
# 287    COMICS  GANMA! - All original stories free of charge f...     4.7
# 288    COMICS                          Röhrich Werner Soundboard     4.7
# 289    COMICS                    Unicorn Pokez - Color By Number     4.8
# 290    COMICS                   MangaToon - Comics updated Daily     3.9
# 291    COMICS               Manga Net – Best Online Manga Reader     4.1
# 292    COMICS                     Manga Rock - Best Manga Reader     4.4
# 293    COMICS                      Manga - read Thai translation     4.6
# 294    COMICS                    The Vietnam Story - Fun Stories     4.5
# 295    COMICS                  Dragon Ball Wallpaper - Ringtones     4.7
# 296    COMICS                                 Funny Jokes Photos     4.4
# ...

# %%
cond_comics = df['Category'] == 'Comics' 
print (cond_comics)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9355    False
# 9356    False
# 9357    False
# 9358    False
# 9359    False
# Name: Category, Length: 9360, dtype: bool

# %%
df_comics = df[df['Category'] == 'COMICS']

# %%
df_comics.head()
# Out:
#     Category                                                App  Rating  \
# 285   COMICS                         LINE WEBTOON - Free Comics     4.5
# 286   COMICS           Manga Master - Best manga & comic reader     4.6
# 287   COMICS  GANMA! - All original stories free of charge f...     4.7
# 288   COMICS                          Röhrich Werner Soundboard     4.7
# 289   COMICS                    Unicorn Pokez - Color By Number     4.8
#
#      Reviews                Size     Installs  Type Price   Content Rating  \
# 285  1013635  Varies with device  10,000,000+  Free     0             Teen
# 286    24005                4.9M     500,000+  Free     0  Adults only 18+
# 287    57106                 27M   1,000,000+  Free     0             Teen
# 288     2249                 32M     500,000+  Free     0         Everyone
# 289      516                 12M      50,000+  Free     0         Everyone
#
#                 Genres       Last Updated         Current Ver  \
# ...

# %%
df_com = df_comics[['Content Rating', 'Rating']]

# %%
df_com.head(5)
# Out:
#       Content Rating  Rating
# 285             Teen     4.5
# 286  Adults only 18+     4.6
# 287             Teen     4.7
# 288         Everyone     4.7
# 289         Everyone     4.8

# %%
df_com.rename(columns={"Content Rating": "Content_Rating"})
# Out:
#        Content_Rating  Rating
# 285              Teen     4.5
# 286   Adults only 18+     4.6
# 287              Teen     4.7
# 288          Everyone     4.7
# 289          Everyone     4.8
# 290        Mature 17+     3.9
# 291        Mature 17+     4.1
# 292              Teen     4.4
# 293              Teen     4.6
# 294          Everyone     4.5
# 295          Everyone     4.7
# 296      Everyone 10+     4.4
# 297          Everyone     4.5
# 298              Teen     3.9
# 299              Teen     3.2
# 300        Mature 17+     3.2
# 301        Mature 17+     4.1
# 302          Everyone     4.5
# 303              Teen     4.2
# 304              Teen     4.2
# 305              Teen     3.7
# 306              Teen     4.5
# 307          Everyone     4.6
# 308          Everyone     4.5
# 309          Everyone     4.7
# 310              Teen     4.4
# 311        Mature 17+     3.5
# 312              Teen     3.3
# 313      Everyone 10+     4.5
# 314        Mature 17+     4.4
# ...

# %%
df_com.columns.values
# Out:
# array(['Content Rating', 'Rating'], dtype=object)

# %%
df_com.rename(columns={"Content Rating": "Content_Rating"}, inplace = True)
# Out:
# C:\Users\inggi\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_com.columns.values
# Out:
# array(['Content_Rating', 'Rating'], dtype=object)

# %%
df_com.Content_Rating.unique
# Out:
# <bound method Series.unique of 285                Teen
# 286     Adults only 18+
# 287                Teen
# 288            Everyone
# 289            Everyone
# 290          Mature 17+
# 291          Mature 17+
# 292                Teen
# 293                Teen
# 294            Everyone
# 295            Everyone
# 296        Everyone 10+
# 297            Everyone
# 298                Teen
# 299                Teen
# 300          Mature 17+
# 301          Mature 17+
# 302            Everyone
# 303                Teen
# 304                Teen
# 305                Teen
# 306                Teen
# 307            Everyone
# 308            Everyone
# 309            Everyone
# 310                Teen
# 311          Mature 17+
# 312                Teen
# 313        Everyone 10+
# 314          Mature 17+
# 315            Everyone
# 316            Everyone
# 317            Everyone
# 318                Teen
# 319            Everyone
# 320            Everyone
# 321            Everyone
# ...

# %%
df_plot =  df_com.groupby('Content_Rating').count()
df_plot.head()
# Out:
#                  Rating
# Content_Rating
# Adults only 18+       2
# Everyone             25
# Everyone 10+          2
# Mature 17+            7
# Teen                 22

# %%
df_plot.plot(kind='bar')

plt.title('Ratings for Comics Category')
plt.ylabel('Number of Ratings')
plt.xlabel('Content Rating')

plt.show()

# %% [markdown]
# 1. Content Rating yang paling banyak diberi penilaian adalah Everyone yang diikuti dengan Teen
# 2. Content Rating dengan tipe Everyone menjadi paling diminati untuk diunduh
